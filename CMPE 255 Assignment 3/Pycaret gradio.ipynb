# %%
# !pip install pycaret gradio --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 53.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.8 MB/s eta 0:00:00
# ...

# %%
from pycaret.datasets import get_data
data=get_data('france')
data.tail()
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France
#      InvoiceNo StockCode                      Description  Quantity  \
# 8552    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 8553    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 8554    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# ...

# %%
from pycaret.classification import *
e=setup(data,target='Country',session_id=150)
# Out:
# <style type="text/css">
# #T_9cb5e_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9cb5e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cb5e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9cb5e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cb5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cb5e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9cb5e_row0_col1" class="data row0 col1" >150</td>
#     </tr>
#     <tr>
#       <th id="T_9cb5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9cb5e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9cb5e_row1_col1" class="data row1 col1" >Country</td>
#     </tr>
#     <tr>
#       <th id="T_9cb5e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_6dd37 th {
#   text-align: left;
# }
# #T_6dd37_row0_col0, #T_6dd37_row0_col6, #T_6dd37_row1_col0, #T_6dd37_row1_col6, #T_6dd37_row2_col0, #T_6dd37_row2_col6, #T_6dd37_row3_col0, #T_6dd37_row3_col6, #T_6dd37_row4_col0, #T_6dd37_row4_col6, #T_6dd37_row5_col0, #T_6dd37_row5_col6, #T_6dd37_row6_col0, #T_6dd37_row6_col6, #T_6dd37_row7_col0, #T_6dd37_row7_col6, #T_6dd37_row8_col0, #T_6dd37_row8_col6, #T_6dd37_row9_col0, #T_6dd37_row9_col6, #T_6dd37_row10_col0, #T_6dd37_row10_col6 {
#   text-align: left;
# }
# ...

# %%
create_app(best_model)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://f2e202b07ee30f1aa7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f2e202b07ee30f1aa7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ![Screenshot 2024-09-20 at 9.15.46 AM.png](data:image/png;base64,...)
